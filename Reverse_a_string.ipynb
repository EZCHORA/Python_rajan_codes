# %% [markdown]
# <a href="https://colab.research.google.com/github/EZCHORA/Python_rajan_codes/blob/main/Reverse_a_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a ="ggggyyyyy"
print("".join(reversed(a)))
# Out:
# yyyyygggg

# %%
b="bbbbbbrrrr"

# %%
print(b[::-1])
# Out:
# rrrrbbbbbb

# %%
d =44444666666
d = str(d)
print(d[::-1])
# Out:
# 66666644444

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input("ente length"))
lst =[]
for i in range(n-1):
  lst.append(int(input("entr denomination")))

# %%
lst
# Out:
# [5, 7, 2, 7, 2, 5, 5]

# %%
a=[]
for i in lst:
  a.append(lst.count(i))

for i in range(n-1):
  if a[i] % 2 !=0:
    print(lst[i])
    break
# Out:
# 5

# %% [markdown]
# 2nd method using sets

# %%
set1 = set(lst)
for i in set1:
  if lst.count(i) % 2 !=0:
      print(lst[i])
      break
# Out:
# 5
